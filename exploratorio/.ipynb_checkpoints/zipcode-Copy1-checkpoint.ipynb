# %%
#ejecutar esta celda para instalar el paquete
# !pip install locationiq
# Out:
# Collecting locationiq
#   Downloading locationiq-0.0.2-py3-none-any.whl (6.5 kB)
# Requirement already satisfied: requests>=2.11.1 in c:\users\anaconda3\lib\site-packages (from locationiq) (2.22.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\anaconda3\lib\site-packages (from requests>=2.11.1->locationiq) (1.25.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\anaconda3\lib\site-packages (from requests>=2.11.1->locationiq) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\anaconda3\lib\site-packages (from requests>=2.11.1->locationiq) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\anaconda3\lib\site-packages (from requests>=2.11.1->locationiq) (2019.11.28)
# Installing collected packages: locationiq
# Successfully installed locationiq-0.0.2
# ERROR: Error checking for conflicts.
# Traceback (most recent call last):
#   File "C:\Users\Anaconda3\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 3021, in _dep_map
#     return self.__dep_map
#   File "C:\Users\Anaconda3\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 2815, in __getattr__
#     raise AttributeError(attr)
# AttributeError: _DistInfoDistribution__dep_map
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Anaconda3\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 3012, in _parsed_pkg_info
#     return self._pkg_info
#   File "C:\Users\Anaconda3\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 2815, in __getattr__
#     raise AttributeError(attr)
# AttributeError: _pkg_info
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Anaconda3\lib\site-packages\pip\_internal\commands\install.py", line 517, in _warn_about_conflicts
#     package_set, _dep_info = check_install_conflicts(to_install)
#   File "C:\Users\Anaconda3\lib\site-packages\pip\_internal\operations\check.py", line 114, in check_install_conflicts
#     package_set, _ = create_package_set_from_installed()
#   File "C:\Users\Anaconda3\lib\site-packages\pip\_internal\operations\check.py", line 53, in create_package_set_from_installed
#     package_set[name] = PackageDetails(dist.version, dist.requires())
#   File "C:\Users\Anaconda3\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 2736, in requires
#     dm = self._dep_map
#   File "C:\Users\Anaconda3\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 3023, in _dep_map
#     self.__dep_map = self._compute_dependencies()
#   File "C:\Users\Anaconda3\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 3032, in _compute_dependencies
#     for req in self._parsed_pkg_info.get_all('Requires-Dist') or []:
#   File "C:\Users\Anaconda3\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 3014, in _parsed_pkg_info
#     metadata = self.get_metadata(self.PKG_INFO)
#   File "C:\Users\Anaconda3\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 1420, in get_metadata
#     value = self._get(path)
#   File "C:\Users\Anaconda3\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 1616, in _get
#     with open(path, 'rb') as stream:
# FileNotFoundError: [Errno 2] No such file or directory: 'c:\\users\\anaconda3\\lib\\site-packages\\PyHamcrest-1.9.0.dist-info\\METADATA'

# %%
import pandas as pd
import time
from locationiq.geocoder import LocationIQ
modelar = pd.read_csv("modelardefinitivo.csv")
#estimar = pd.read_csv("estimardifinitivo.csv")
modelar = modelar.reset_index()
modelar = modelar.drop(columns="index")
modelar = modelar.drop(columns="Unnamed: 0")
#estimar = estimar.drop(columns="Unnamed: 0")

# %%
#PONER VUESTRA API KEY
#OS REGISTRAIS AQUI: https://locationiq.com/register
#una vez registrado os lleva directamente a una pagina donde os pone vuestra API key
geocoder = LocationIQ("d5ec0b5cc1d692")

# %%
modelar["place_id"]=""
modelar["license"]=""
modelar["lat"]=""
modelar["lon"]=""
modelar["display_name"]=""
modelar["boundingbox1"]=""
modelar["boundingbox2"]=""
modelar["boundingbox3"]=""
modelar["boundingbox4"]=""
modelar["importance"]=1.1
modelar["house_number"]=""
modelar["road"]=""
modelar["neighbourhood"]=""
modelar["city"]=""
modelar["state"]=""
modelar["country"]=""
modelar["postcode"]=""
modelar["country_code"]=""
modelar.columns
modelar
# Out:
#                       ID           X          Y     Q_R_4_0_0   Q_R_4_0_1  \
# 0       35984B9C3E7CD9A1  2207357872  165920300  0.000000e+00  443.001300
# 1       F9D04BF6D037F8FB  2189757160  165463267  5.879611e-05  443.899011
# 2       B89D5711AFF8C423  2240147335  165690752  0.000000e+00  353.502274
# 3       1C3478AC1522E7E4  2227146459  165934099  0.000000e+00  268.000613
# 4       4D12AA5009064345  2212350459  165681791  0.000000e+00  318.997910
# ...                  ...         ...        ...           ...         ...
# 103225  C5FD596EB22DB167  2225843339  165482267  2.183254e-11  427.999246
# 103226  A51D42F2EAB0E15E  2196745557  165159412  1.108565e-06  544.002496
# 103227  9B75473FE6396523  2261090490  165673813  0.000000e+00  572.003784
# 103228  3E566F8A461FDBA3  2219731066  165775921  0.000000e+00  341.999185
# 103229  0E6F8A7388F1FF25  2260508805  165584719  4.849879e-11  400.998581
#
#          Q_R_4_0_2   Q_R_4_0_3    Q_R_4_0_4    Q_R_4_0_5    Q_R_4_0_6  ...  \
# 0       616.001697  746.998401   872.996472  1009.000946  1159.002319  ...
# 1       627.999060  770.001611   904.999988  1032.998474  1165.001636  ...
# 2       523.003601  644.001831   760.997131   876.999634  1006.997498  ...
# 3       376.999609  478.003784   575.001233   683.997742   809.005994  ...
# 4       492.003845  632.999634   757.002197   882.999908  1019.008911  ...
# ...            ...         ...          ...          ...          ...  ...
# 103225  604.004626  742.996454   866.005859   990.999512  1124.001465  ...
# 103226  690.999658  812.997748   933.008777  1055.998779  1187.997485  ...
# 103227  765.000366  924.996460  1097.998169  1329.000732  1609.997925  ...
# 103228  508.998688  644.999683   767.999805   889.001648  1019.992651  ...
# 103229  570.003540  684.001343   800.005432   932.995483  1089.997925  ...
#
#         boundingbox4  importance  house_number  road  neighbourhood  city  \
# 0                            1.1
# 1                            1.1
# 2                            1.1
# 3                            1.1
# 4                            1.1
# ...              ...         ...           ...   ...            ...   ...
# 103225                       1.1
# 103226                       1.1
# 103227                       1.1
# 103228                       1.1
# 103229                       1.1
#
#         state  country  postcode  country_code
# 0
# 1
# 2
# 3
# 4
# ...       ...      ...       ...           ...
# 103225
# 103226
# 103227
# 103228
# 103229
#
# [103230 rows x 76 columns]

# %%
###ESTA ES LA CELDA QUE TENEIS QUE DEJAR EJECUTANDO.
##CAMBIAR EL RANGO CADA UNO SEGUN LO QUE OS TOQUE. 
#MANU DEL 30000 AL 65000 
#PABLO DEL 65001 AL 95001
#HAY QUE HACER 10000 CADA DÍA SI ALGUIEN ESTA DISPUESTO A HACERSE OTRA CUENTA EN EL PORTATIL DEL CURRO LO PODEMOS HACER
#MAS RAPIDO
for fila in range(85000,95000): 
    datos = geocoder.reverse_geocode(modelar.iloc[fila,57],modelar.iloc[fila,56])   
    try:
        modelar.iloc[fila,58]=datos["place_id"]
    except:
        modelar.iloc[fila,58]="no disponible"
    try:
        modelar.iloc[fila,59]=datos["licence"]
    except:
        modelar.iloc[fila,59]="no disponible"
    try:
        modelar.iloc[fila,60]=datos["lat"]
    except:    
        modelar.iloc[fila,60]="no disponible"
    try:
        modelar.iloc[fila,61]=datos["lon"]
    except:
        modelar.iloc[fila,61]="no disponible"
    try:
        modelar.iloc[fila,62]=datos["display_name"]
    except:
        modelar.iloc[fila,62]="no disponible"
    try:
        modelar.iloc[fila,63]=datos["boundingbox"][0]
    except:
        modelar.iloc[fila,63]="no disponible"
    try:
        modelar.iloc[fila,64]=datos["boundingbox"][1]
    except:    
        modelar.iloc[fila,64]="no disponible"
    try:
        modelar.iloc[fila,65]=datos["boundingbox"][2]
    except:
        modelar.iloc[fila,65]="no disponible"
    try:
        modelar.iloc[fila,66]=datos["boundingbox"][3]
    except:
        modelar.iloc[fila,66]="no disponible"
    try:
        modelar.iloc[fila,67]=datos["importance"]
    except:
        modelar.iloc[fila,67]="no disponible"
    try:
        modelar.iloc[fila,68]=datos["address"]["house_number"]
    except:   
        modelar.iloc[fila,68]="no disponible"
    try:
        modelar.iloc[fila,69]=datos["address"]["road"]
    except:
        modelar.iloc[fila,69]="no disponible"
    try:
        modelar.iloc[fila,70]=datos["address"]["neighbourhood"]
    except:
        modelar.iloc[fila,70]="no disponible"
    try:
        modelar.iloc[fila,71]=datos["address"]["city"]
    except:
        modelar.iloc[fila,71]="no disponible"
    try:
        modelar.iloc[fila,72]=datos["address"]["state"]
    except:    
        modelar.iloc[fila,72]="no disponible"
    try:    
        modelar.iloc[fila,73]=datos["address"]["country"]
    except:    
        modelar.iloc[fila,73]="no disponible"
    try:    
        modelar.iloc[fila,74]=datos["address"]["postcode"]
    except:
        modelar.iloc[fila,74]="no disponible"
    try:
        modelar.iloc[fila,75]=datos["address"]["country_code"]
    except:
        modelar.iloc[fila,75]="no disponible"
    time.sleep(1)
modelar.head()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# C:\Users\Anaconda3\lib\site-packages\locationiq\geocoder.py in request(self, method, params, headers)
#     131             self.code = res.status_code
# --> 132             res.raise_for_status()
#     133             return self.data
#
# C:\Users\Anaconda3\lib\site-packages\requests\models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 429 Client Error: Too Many Requests for url: https://locationiq.org/v1/reverse.php?key=d5ec0b5cc1d692&lat=40.46867020608975&lon=-3.699505807882191&format=json&addressdetails=1&limit=10&accept-language=en
#
# During handling of the above exception, another exception occurred:
#
# LocationIqRequestLimitExeceeded           Traceback (most recent call last)
# <ipython-input-17-811c778c32fe> in <module>
#       6 #MAS RAPIDO
#       7 for fila in range(85000,95000):
# ----> 8     datos = geocoder.reverse_geocode(modelar.iloc[fila,57],modelar.iloc[fila,56])
#       9     try:
#      10         modelar.iloc[fila,58]=datos["place_id"]
#
# C:\Users\Anaconda3\lib\site-packages\locationiq\geocoder.py in reverse_geocode(self, lat, lon)
#      90
#      91         r = LocationIqRequest(url)
# ---> 92         r.get(data, self.headers)
#      93         return r.response
#      94
#
# C:\Users\Anaconda3\lib\site-packages\locationiq\geocoder.py in get(self, params, headers)
#     152         :return response: Response
#     153         """
# --> 154         self.response = self.request("GET", params=params, headers=headers)
#     155
#     156
#
# C:\Users\Anaconda3\lib\site-packages\locationiq\geocoder.py in request(self, method, params, headers)
#     137                 raise LocationIqError.factory(res.status_code, "No location or places were found for the given input")
#     138             else:
# --> 139                 raise LocationIqError.factory(res.status_code, self.data['error'])
#     140         except requests.exceptions.HTTPError as errh:
#     141             raise LocationIqError.factory(res.status_code, errh)
#
# LocationIqRequestLimitExeceeded: (429, 'Rate Limited Day')

# %%
#esto es para ver donde se os ha cortado tendriais que cambiar los rangos y demas para poder ver hasta donde ha llegado
count=0
for fila in range(85000,95000):
    count=count+1
    if modelar.iloc[fila,67]==1.1:
        break
print(count)
# Out:
# 9999

# %%
modelar.iloc[84999,67]
# Out:
# 0.225

# %%
modelar1 = modelar.iloc[75001:84999,]

# %%
#guardar con el nombre indicando en que rango estan actualizados los datos cuidado con no cambiar esto
#y pisar datos anteriores que la liamos 
modelar1.to_csv("modelar_75001-84999.csv")
